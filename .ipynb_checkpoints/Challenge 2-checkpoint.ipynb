# %% [markdown]
# #### CHALLENGE 2

# %%
from azure.cognitiveservices.vision.customvision.prediction import prediction_endpoint
from azure.cognitiveservices.vision.customvision.prediction.prediction_endpoint import models
from azure.cognitiveservices.vision.customvision.training import training_api
from azure.cognitiveservices.vision.customvision.training.models import ImageFileCreateEntry, Region

import matplotlib.pyplot as plt
import matplotlib.patches as patches
import os
import numpy as np
from PIL import Image

# %% [markdown]
# ### CREATE PROJECT

# %%
from azure.cognitiveservices.vision.customvision.training import CustomVisionTrainingClient
from azure.cognitiveservices.vision.customvision.training.models import ImageUrlCreateEntry

ENDPOINT = "https://southcentralus.api.cognitive.microsoft.com"

# Replace with a valid key
training_key = "806abc512abd4fb393a3e8604ebefa59"
prediction_key = "e77a589a49314c1384e3954adb03b2eb"

trainer = CustomVisionTrainingClient(training_key, endpoint=ENDPOINT)

# Create a new project
print ("Creating project...")
project = trainer.create_project("Challenge2")
# Out:
# Creating project...

# %%
# Make two tags in the new project
hardshell_jacket = trainer.create_tag(project.id, "hardshell jacket ")
insulated_jacket = trainer.create_tag(project.id, "insulated jacket")

print(project.id)
# Out:
# 0297f20f-e010-4bb4-8912-467c83bd27d7

# %%
import time

print ("Training...")
iteration = trainer.train_project(project.id)
while (iteration.status != "Completed"):
    iteration = trainer.get_iteration(project.id, iteration.id)
    print ("Training status: " + iteration.status)
    time.sleep(1)

# The iteration is now trained. Make it the default project endpoint
trainer.update_iteration(project.id, iteration.id, is_default=True)
print ("Done!")
# Out:
# Training...
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Completed
# Done!

# %% [markdown]
# #### PREDICTION

# %%
'''The script will help to call the Custom Vision API to detect probabilities and bounding boxes of an image'''

from azure.cognitiveservices.vision.customvision.prediction import prediction_endpoint
from azure.cognitiveservices.vision.customvision.prediction.prediction_endpoint import models
from azure.cognitiveservices.vision.customvision.training import training_api
from azure.cognitiveservices.vision.customvision.training.models import ImageFileCreateEntry, Region

import matplotlib.pyplot as plt
import matplotlib.patches as patches
import os
import numpy as np
from PIL import Image

from azure.cognitiveservices.vision.customvision.prediction import CustomVisionPredictionClient
from azure.cognitiveservices.vision.customvision.prediction.prediction_endpoint import models

# Now there is a trained endpoint that can be used to make a prediction

predictor = CustomVisionPredictionClient(prediction_key, endpoint=ENDPOINT)

test_img_url = os.path.join(os.getcwd(),"test_images","T1.jpeg")

# %%
def call_api(img_file):

        '''Process the API call so that the response is channelized'''

        import requests

        file_url='https://southcentralus.api.cognitive.microsoft.com/customvision/v2.0/Prediction/0297f20f-e010-4bb4-8912-467c83bd27d7/image'

        file_headers={'Prediction-Key':prediction_key,'Content-Type':'application/octet-stream'}
        
        base_model_file = os.path.join(os.getcwd(),"test_images")

        image_file=os.path.join(base_model_file,img_file)

        with open(image_file,mode='rb') as test_data:
            fresponse=requests.post(url=file_url,headers=file_headers,data=test_data)
            
        from PIL import Image
        im=Image.open(image_file)
        plt.imshow(im)
        tmp=0
        for i in response.json()['predictions']:
            maxprob=max(tmp,i['probability'])
            maxtag=i['tagName']
            tmp=maxprob   

        plt.title(maxtag)
        plt.show()
        label=[i['tagName'] for i in response.json()['predictions'] if i['probability']>0.9]
        print(fresponse.json())
        
        return fresponse
        
          

response=call_api("859910.jpeg")

response=call_api("insulated_test/105017.jpeg")

response= call_api("hardshell_test/117497.jpeg")
# Out:
# {'id': '5bed32c7-183a-4853-abca-5dbd63a607ad', 'project': '0297f20f-e010-4bb4-8912-467c83bd27d7', 'iteration': '943b6a18-d9a0-4b4c-9ea3-5599a282d08c', 'created': '2018-11-27T07:32:50.4079399Z', 'predictions': [{'probability': 0.0192404985, 'tagId': '0f0da9f1-9777-4ea1-8f9e-bfedb63dc555', 'tagName': 'insulated jacket'}, {'probability': 0.00363263, 'tagId': 'd1261911-ef8a-43b7-a197-a048bcc5859f', 'tagName': 'hardshell jacket'}]}
# {'id': 'a820a0bc-c621-4692-a5f1-ced44760c47c', 'project': '0297f20f-e010-4bb4-8912-467c83bd27d7', 'iteration': '943b6a18-d9a0-4b4c-9ea3-5599a282d08c', 'created': '2018-11-27T07:32:51.484974Z', 'predictions': [{'probability': 0.87966, 'tagId': 'd1261911-ef8a-43b7-a197-a048bcc5859f', 'tagName': 'hardshell jacket'}, {'probability': 0.3495718, 'tagId': '0f0da9f1-9777-4ea1-8f9e-bfedb63dc555', 'tagName': 'insulated jacket'}]}
# ...

# %%
problist=[]

response.json()['predictions']['probability']
# Out:
# [{'probability': 0.9932625,
#   'tagId': 'd1261911-ef8a-43b7-a197-a048bcc5859f',
#   'tagName': 'hardshell jacket'},
#  {'probability': 0.007383764,
#   'tagId': '0f0da9f1-9777-4ea1-8f9e-bfedb63dc555',
#   'tagName': 'insulated jacket'}]

# %% [raw]
#
#
# def detect_objects_from_cv(training_key,prediction_key,project_id,image_file):
#
#     '''Script to invoke custom vision Image object detection results '''
#
#     trainer=training_api.TrainingApi(training_key)
#     project=trainer.get_project(project_id)
#     predictor = prediction_endpoint.PredictionEndpoint(prediction_key)
#     with open(image_file,mode='rb') as test_data:
#         detection_result=predictor.predict_image(project.id,test_data)
#
#     return detection_result,test_data
#
# project_id=project.id
# detection_training_key=training_key
# detection_prediction_key=prediction_key
#
# base_folder = os.getcwd()
# base_model_file = os.path.join(base_folder, "..", "Data", "Test","Screwdriver")
#
# image_file=os.path.join(base_model_file,"T1.jpg")
#
#
# def detect_locations(pr_threshold=30,image_file=image_file):
#
#     '''Function to plot objects identified in the image above a certain probability threshold'''
#
#     detection_result,t=detect_objects_from_cv(training_key=detection_training_key,prediction_key=detection_prediction_key,project_id=project_id,image_file=image_file)
#     for prediction in detection_result.predictions:
#         print ("\t" + prediction.tag_name + ": {0:.2f}%".format(prediction.probability * 100), prediction.bounding_box.left, prediction.bounding_box.top, prediction.bounding_box.width, prediction.bounding_box.height)
#
#
#
#
#
# def prepare_api():
#
#         '''Process the API call so that the response is channelized'''
#
#         import requests
#
#         url='https://southcentralus.api.cognitive.microsoft.com/customvision/v2.0/Prediction/fd57bbb7-bcff-4cf8-836b-8ef9ea9b7009/url?iterationId=70ee49bc-3637-4a46-9d88-2c98626a182f'
#
#         headers={'Prediction-Key':'de2eb01c04b047908a018b8fa066fa86','Content-Type':'application/json'}
#
#         body={"url":"https://bhppocstorage.blob.core.windows.net/hmd/T1.jpg?sp=r&st=2018-11-21T07:18:08Z&se=2018-11-21T15:18:08Z&spr=https&sv=2017-11-09&sig=j2j13Jp5FjLyzsMHUiQAxAKzneUsYAm3pdLvscUHMzg%3D&sr=b"}
#
#
#         #response=requests.post(url,headers=headers,json=body)
#
#         #print(response.json())
#
#
#         file_url='https://southcentralus.api.cognitive.microsoft.com/customvision/v2.0/Prediction/fd57bbb7-bcff-4cf8-836b-8ef9ea9b7009/image?iterationId=70ee49bc-3637-4a46-9d88-2c98626a182f'
#
#         file_headers={'Prediction-Key':'de2eb01c04b047908a018b8fa066fa86','Content-Type':'application/octet-stream'}
#
#         image_file=os.path.join(base_model_file,"T1.jpg")
#
#         with open(image_file,mode='rb') as test_data:
#                 pass
#
#                 #fresponse=requests.post(url=file_url,headers=file_headers,data=test_data)
#
#         #print(fresponse.json())
#
#         apim_url='https://ipstest.azure-api.net/imageclassify'
#
#         #apim_url='https://ipstest.azure-api.net/fd57bbb7-bcff-4cf8-836b-8ef9ea9b7009/url?iterationId=70ee49bc-3637-4a46-9d88-2c98626a182f'
#
#         #res=requests.post(apim_url,headers={'Ocp-Apim-Subscription-Key':'23dbb585f43c484e8a008a874a1dc9ab','Prediction-Key':'de2eb01c04b047908a018b8fa066fa86'},json=body)
#
#         #res=requests.post(apim_url,json=body,headers={'Ocp-Apim-Subscription-Key':'23dbb585f43c484e8a008a874a1dc9ab'})
#
#         res=requests.post(apim_url,json=body)
#
#         print(res.json())
#
#
#
# ##Calls
# #detect_locations(pr_threshold=30)
#
# prepare_api()
